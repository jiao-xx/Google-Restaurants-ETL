# %%
import requests
import time

# %%
# Replace YOUR_API_KEY with your actual API key
api_key = "xxxxxx"

# Define the endpoint URL
url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

# Define the parameters
params = {
    'query': 'Vegan Restaurant',
    'location': '43.698431, -79.443665',  # Latitude and Longitude for London, ON
    'radius': 2079.95,  # Search within a '5000' meters radius
    'key': api_key
}

# %%
# Function to get place details
def get_place_details(place_id):
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=formatted_phone_number,website&key={api_key}"
    details_response = requests.get(details_url)
    
    if details_response.status_code == 200:
        details = details_response.json().get('result', {})
        phone_number = details.get('formatted_phone_number', 'Not Available')
        website = details.get('website', 'Not Available')
    else:
        phone_number = 'Not Available'
        website = 'Not Available'
    
    return phone_number, website

def get_places(url, params):
    response = requests.get(url, params=params)
    if response.status_code == 200:
        results = response.json().get('results', [])
        next_page_token = response.json().get('next_page_token', None)
        
        for place in results:
            name = place.get('name')
            address = place.get('formatted_address')
            rating = place.get('rating', 'Not Available')
            place_id = place.get('place_id')
            phone_number, website = get_place_details(place_id)
            
            print(f"Name: {name}")
            print(f"Address: {address}")
            print(f"Rating: {rating}")
            print(f"Phone Number: {phone_number}")
            print(f"Website: {website}")
            print("------")
        
        return next_page_token
    else:
        print("Failed to retrieve data!")
        return None

next_page_token = get_places(url, params)

# Handle pagination
while next_page_token:
    time.sleep(2)  # Add a delay before the next request as per Google's guidelines
    params['pagetoken'] = next_page_token
    next_page_token = get_places(url, params)
# Out:
# Name: Irie Veggie Takeout
# Address: 2593 Eglinton Ave W, York, ON M6M 1T3, Canada
# Rating: 4.5
# Phone Number: (416) 653-4825
# Website: Not Available
# ------
# Name: V's Caribbean Restaurant Inc.
# Address: 1221 Weston Rd, York, ON M6M 4P7, Canada
# Rating: 4.8
# Phone Number: (416) 249-1221
# Website: https://linktr.ee/veezvegan
# ------
# Name: PLANTA
# Address: 1221 Bay St., Toronto, ON M5R 3P5, Canada
# Rating: 4.4
# Phone Number: (647) 812-1221
# Website: https://www.plantarestaurants.com/location/planta-toronto/
# ------
# Name: Auleaf
# Address: 3023 Bathurst St, North York, ON M6B 3B5, Canada
# Rating: 4.5
# Phone Number: (416) 783-2323
# Website: https://www.facebook.com/pg/AuleafCafe/about/
# ------
# Name: Thien Tam Asia Vegan & vegetarian restaurant
# Address: 2907 Dundas St W, Toronto, ON M6P 1Z1, Canada
# Rating: 4.7
# Phone Number: (416) 368-1368
# Website: http://thientamca.com/
# ------
# Name: Eat Nabati
# Address: 160 Baldwin St, Toronto, ON M5T 3K7, Canada
# Rating: 4.7
# Phone Number: (289) 277-0008
# Website: https://eatnabati.com/
# ------
# Name: Happy Taco (located inside Eva's Original)
# Address: 454 Bloor St W, Toronto, ON M5S 1X8, Canada
# Rating: 4.5
# Phone Number: (416) 519-2840
# Website: https://happytacoshop.com/
# ------
# Name: Fresh Kitchen + Juice Bar
# Address: 101 Eglinton Ave E, Toronto, ON M4P 1H4, Canada
# Rating: 4.4
# Phone Number: (647) 789-5480
# Website: https://www.freshkitchens.ca/en/locations/on/toronto/101-eglinton-avenue-east
# ------
# Name: Buddha's Vegan Restaurant
# Address: 666 Dundas St W, Toronto, ON M5T 1H9, Canada
# Rating: 4.6
# Phone Number: (416) 603-3811
# Website: http://www.buddharestaurant.ca/
# ------
